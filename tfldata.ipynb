# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api.tfl.gov.uk/Journey/JourneyResults/SW19%202NZ/to/EC3M%208AF?timeIs=Arriving&journeyPreference=LeastInterchange&accessibilityPreference=NoRequirements&walkingSpeed=Slow&cyclePreference=None&bikeProficiency=Easy"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# 200
# b'{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.ItineraryResult, Tfl.Api.Presentation.Entities","journeys":[{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, Tfl.Api.Presentation.Entities","startDateTime":"2024-04-05T11:11:00","duration":44,"arrivalDateTime":"2024-04-05T11:55:00","alternativeRoute":false,"legs":[{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities","duration":10,"instruction":{"$type":"Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities","summary":"Walk to Colliers Wood Station","detailed":"Walk to Colliers Wood Station","steps":[{"$type":"Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities","description":"Christchurch Close for 135 metres","turnDirection":"STRAIGHT","streetName":"Christchurch Close","distance":135,"cumulativeDistance":135,"skyDirection":262,"skyDirectionDescription":"West","cumulativeTravelTime":120,"latitude":51.41581866257,"longitude":-0.1762808718,"pathAttribute":{"$type":"Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"},"descriptionHeading":"Continue along ","trackType":"None"},{"$type":"Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities","description":"on to Christchurch Road, continue for 269 metres","turnDirection":"RIGHT","streetName":"Christchurch Road","distance":269,"cumulativeDistance":404,"skyDirection":4,"skyDirectionDescription":"North","cumulativeTravelTime":363,"latitude":51.41565966445,"longitude":-0.17819990435,"pathAttribute":{"$type":"Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"},"descriptionHeading":"Turn right","trackType":"None"},{"$type":"Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities","description":"on to High Street Colliers Wood, continue for 13 metres","turnDirection":"RIGHT","streetName":"High Street Colliers Wood","distance":13,"cumulativeDistance":417,"skyDirection":30,"skyDirectionDescription":"NorthEast","cumulativeTravelTime":375,"latitude":51.41798234314,"longitude":-0.17836643278,"pathAttribute":{"$type":"Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"},"descriptionHeading":"Turn right","trackType":"None"}]},"obstacles":[{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities","type":"WALKWAY","incline":"LEVEL","stopId":1000055,"position":"IDEST"},{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities","type":"ESCALATOR","incline":"DOWN","stopId":1000055,"position":"IDEST"}],"departureTime":"2024-04-05T11:11:00","arrivalTime":"2024-04-05T11:21:00","departurePoint":{"$type":"Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities","platformName":"","icsCode":"99999997","commonName":"SW19 2NZ","placeType":"StopPoint","additionalProperties":[],"lat":51.41598132379,"lon":-0.17633192350000002},"arrivalPoint":{"$type":"Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities","naptanId":"940GZZLUCSD","platformName":"","icsCode":"1000055","individualStopId":"9400ZZLUCSD1","commonName":"Colliers Wood Underground Station","placeType":"StopPoint","additionalProperties":[],"lat":51.41867148942,"lon":-0.17757677895},"path":{"$type":"Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities","lineString":"[[51.41598132379, -0.17633192350],[51.41581866257, -0.17628087180],[51.41576626288, -0.17695887705],[51.41576648645, -0.17697324943],[51.41565966445, -0.17819990435],[51.41628764047, -0.17810303082],[51.41664600504, -0.17801687466],[51.41678957429, -0.17799678451],[51.41732902026, -0.17798971638],[51.41784284572, -0.17806995823],[51.41798234314, -0.17836643278],[51.41804435882, -0.17830643935],[51.41807963676, -0.17826189081],[51.41807959533, -0.17826188757],[51.41814862856, -0.17807218157],[51.41865259533, -0.17751998757]]","stopPoints":[],"elevation":[]},"routeOptions":[{"$type":"Tfl.Api.Prese ...

# %%
import urllib.request
import json

try:
    url = "https://api.tfl.gov.uk/Journey/JourneyResults/CR4%203LY/to/EC3M%208AF?timeIs=Arriving&journeyPreference=LeastInterchange&accessibilityPreference=NoRequirements&walkingSpeed=Slow&cyclePreference=None&bikeProficiency=Easy"
    hdr = {'Cache-Control': 'no-cache'}

    req = urllib.request.Request(url, headers=hdr)
    response = urllib.request.urlopen(req)

    # Read the response
    response_data = response.read()

    # Parse the response data as JSON
    data = json.loads(response_data)

    # Now you can work with 'data' as a Python dictionary
    print(json.dumps(data, indent=2))  # This is for pretty printing the JSON data

except Exception as e:
    print(e)
# Out:
# {
#   "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.ItineraryResult, Tfl.Api.Presentation.Entities",
#   "journeys": [
#     {
#       "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, Tfl.Api.Presentation.Entities",
#       "startDateTime": "2024-04-05T11:03:00",
#       "duration": 52,
#       "arrivalDateTime": "2024-04-05T11:55:00",
#       "alternativeRoute": false,
#       "legs": [
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 18,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Walk to Colliers Wood Station",
#             "detailed": "Walk to Colliers Wood Station",
#             "steps": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "Fleming Mead for 134 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Fleming Mead",
#                 "distance": 134,
#                 "cumulativeDistance": 134,
#                 "skyDirection": 304,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 120,
#                 "latitude": 51.41781204587,
#                 "longitude": -0.16686766494,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Myrna Close, continue for 106 metres",
#                 "turnDirection": "SLIGHT_RIGHT",
#                 "streetName": "Myrna Close",
#                 "distance": 106,
#                 "cumulativeDistance": 240,
#                 "skyDirection": 307,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 215,
#                 "latitude": 51.41743594319,
#                 "longitude": -0.16869481987,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "for 91 metres",
#                 "turnDirection": "SLIGHT_RIGHT",
#                 "streetName": "",
#                 "distance": 91,
#                 "cumulativeDistance": 331,
#                 "skyDirection": 290,
#                 "skyDirectionDescription": "West",
#                 "cumulativeTravelTime": 297,
#                 "latitude": 51.417323139009994,
#                 "longitude": -0.17010874215,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Devonshire Road, continue for 42 metres",
#                 "turnDirection": "SHARP_RIGHT",
#                 "streetName": "Devonshire Road",
#                 "distance": 42,
#                 "cumulativeDistance": 373,
#                 "skyDirection": 67,
#                 "skyDirectionDescription": "NorthEast",
#                 "cumulativeTravelTime": 334,
#                 "latitude": 51.41755699873,
#                 "longitude": -0.17126433237,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a sharp right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Cavendish Road, continue for 530 metres",
#                 "turnDirection": "LEFT",
#                 "streetName": "Cavendish Road",
#                 "distance": 530,
#                 "cumulativeDistance": 903,
#                 "skyDirection": 334,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 813,
#                 "latitude": 51.41770125427,
#                 "longitude": -0.17071206321,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Turn left",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to High Street Colliers Wood, continue for 82 metres",
#                 "turnDirection": "SLIGHT_LEFT",
#                 "streetName": "High Street Colliers Wood",
#                 "distance": 82,
#                 "cumulativeDistance": 985,
#                 "skyDirection": 211,
#                 "skyDirectionDescription": "SouthWest",
#                 "cumulativeTravelTime": 886,
#                 "latitude": 51.418911904320005,
#                 "longitude": -0.17742339400999999,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight left",
#                 "trackType": "None"
#               }
#             ]
#           },
#           "obstacles": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000055,
#               "position": "IDEST"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "DOWN",
#               "stopId": 1000055,
#               "position": "IDEST"
#             }
#           ],
#           "departureTime": "2024-04-05T11:03:00",
#           "arrivalTime": "2024-04-05T11:21:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "platformName": "",
#             "icsCode": "99999997",
#             "commonName": "CR4 3LY",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.417983922619996,
#             "lon": -0.16693269860999999
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUCSD",
#             "platformName": "",
#             "icsCode": "1000055",
#             "individualStopId": "9400ZZLUCSD1",
#             "commonName": "Colliers Wood Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.41867148942,
#             "lon": -0.17757677895
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.41798392262, -0.16693269861],[51.41781204587, -0.16686766494],[51.41773903025, -0.16737395288],[51.41743594319, -0.16869481987],[51.41754738028, -0.16892047567],[51.41732313901, -0.17010874215],[51.41740963178, -0.17046483304],[51.41735885072, -0.17066820558],[51.41738153554, -0.17096931754],[51.41755699873, -0.17126433237],[51.41766687658, -0.17081410882],[51.41770125427, -0.17071206321],[51.41841975140, -0.17122989875],[51.41864171866, -0.17162374065],[51.41878367680, -0.17265359639],[51.41885753716, -0.17393067094],[51.41890278052, -0.17625879406],[51.41891190432, -0.17742339401],[51.41845150654, -0.17788755291],[51.41829219777, -0.17805209081],[51.41830119533, -0.17805168757],[51.41814862856, -0.17807218157],[51.41865259533, -0.17751998757]]",
#             "stopPoints": [],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "",
#               "directions": [
#                 ""
#               ],
#               "direction": ""
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "walking",
#             "name": "walking",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "100",
#             "network": ""
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "distance": 985.0,
#           "isDisrupted": false,
#           "hasFixedLocations": true,
#           "scheduledDepartureTime": "2024-04-05T11:03:00",
#           "scheduledArrivalTime": "2024-04-05T11:21:00",
#           "interChangeDuration": "3",
#           "interChangePosition": "IDEST"
#         },
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 23,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Northern line to Bank",
#             "detailed": "Northern line towards Golders Green Station via Bank",
#             "steps": []
#           },
#           "obstacles": [],
#           "departureTime": "2024-04-05T11:21:00",
#           "arrivalTime": "2024-04-05T11:44:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUCSD",
#             "platformName": "",
#             "icsCode": "1000055",
#             "individualStopId": "9400ZZLUCSD1",
#             "commonName": "Colliers Wood Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.41867148942,
#             "lon": -0.17757677895
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUBNK",
#             "platformName": "",
#             "icsCode": "1000013",
#             "individualStopId": "9400ZZLUBNK4",
#             "commonName": "Bank Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.51231267497,
#             "lon": -0.08789045923
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.41865453159, -0.17752466317],[51.42004167281, -0.17605525225],[51.42051261610, -0.17569131773],[51.42098221542, -0.17524113162],[51.42190455397, -0.17441331916],[51.42287789609, -0.17339645375],[51.42350342533, -0.17256602482],[51.42429588915, -0.17148438326],[51.42508182381, -0.17056119084],[51.42552511443, -0.17015510970],[51.42668916494, -0.16925991069],[51.42714098846, -0.16882469139],[51.42780359581, -0.16810627263],[51.42780359581, -0.16810627263],[51.42916596914, -0.16662906493],[51.43083885686, -0.16492209173],[51.43135267122, -0.16442675961],[51.43160047801, -0.16417226097],[51.43218753599, -0.16376029380],[51.43273236097, -0.16352264912],[51.43320393799, -0.16320161573],[51.43361102797, -0.16278245426],[51.43411471844, -0.16221553814],[51.43488730261, -0.16101916030],[51.43520158169, -0.16041665528],[51.43572319044, -0.15927346977],[51.43587418287, -0.15905448961],[51.43587418287, -0.15905448961],[51.43654966492, -0.15807483129],[51.43735278320, -0.15710729855],[51.43762753383, -0.15685164124],[51.43816132106, -0.15648483345],[51.43902694365, -0.15606148735],[51.44009609524, -0.15542848039],[51.44095944991, -0.15486129450],[51.44399160676, -0.15225676731],[51.44399160676, -0.15225676731],[51.44468590878, -0.15166032709],[51.44511070155, -0.15122584896],[51.44534005021, -0.15094316431],[51.44587554227, -0.15011564918],[51.44625425965, -0.14961105305],[51.44668040675, -0.14926283198],[51.44759719549, -0.14866450053],[51.44859486238, -0.14806287207],[51.44904238673, -0.14792962974],[51.45110663277, -0.14767338424],[51.45177256774, -0.14770400099],[51.45230188195, -0.14762500560],[51.45294370606, -0.14726798660],[51.45328008596, -0.14699203546],[51.45328008596, -0.14699203546],[51.45364502598, -0.14669264955],[51.45559254936, -0.14474257091],[51.45705419429, -0.14334463493],[51.45816364421, -0.14242154005],[51.45946066858, -0.14141880462],[51.45984139848, -0.14104345804],[51.46013248737, -0.14068614349],[51.46115167299, -0.13917636997],[51.46168593406, -0.13827649603],[51.46194685465, -0.13771883487],[51.46219535667, -0.13694573380],[51.46223616889, -0.13678463157],[51.46223616889, -0.13678463157],[51.46242382149, -0.13604387641],[51.46264718254, -0.13538695146],[51.46349170934, -0.13307790329],[51.46426287774, -0.13124685439],[51.46471619555, -0.13035013310],[51.46505034827, -0.12987577569],[51.46549279874, -0.12942577641],[51.46570744264, -0.12927772237],[51.46570744264, -0.12927772237],[51.46751188618, -0.12803301723],[51.46813268438, -0.12748928683],[51.46858296234, -0.12696692276],[51.46976142379, -0.12530604484],[51.47049213046, -0.12432578557],[51.47139357547, -0.12333848806],[51.47180905450, -0.12286171332],[51.47180905450, -0.12286171332],[51.47287706873, -0.12163608392],[51.47311625063, -0.12141026805],[51.47340036541, -0.12118260365],[51.47460409854, -0.11998115399],[51.47499281926, -0.11954757148],[51.47564721317, -0.11885824934],[51.47737050325, -0.11697285257],[51.47799907712, -0.11635652516],[51.47921081858, -0.11509688795],[51.48131352004, -0.11276347811],[51.48155300626, -0.11255231007],[51.48155300626, -0.11255231007],[51.48283859238, -0.11141869439],[51.48440556499, -0.10988484800],[51.48585476168, -0.10829815511],[51.48773893155, -0.10636204829],[51.48791610582, -0.10619626235],[51.48843749893, -0.10568255305],[51.48843749893, -0.10568255305],[51.48924385794, -0.10488804945],[51.49046468700, -0.10364181592],[51.49155559532, -0.10270342011],[51.49282122758, -0.10089338082],[51.49315851894, -0.10062005911],[51.49354307425, -0.10048882730],[51.49480375326, -0.10059488862],[51.49499201222, -0.10053355917],[51.49499201222, -0.10053355917],[51.49510789605, -0.10049580723],[51.49586405413, -0.09998895309],[51.49664926916, -0.09961053500],[51.49711855449, -0.09915880487],[51.49823217976, -0.09795988205],[51.49906884606, -0.09687329133],[51.50011042139, -0.09511535238],[51.50057266965, -0.09423159047],[51.50099315377, -0.09350892153],[51.50099315377, -0.09350892153],[51.50105382 ...
#             "stopPoints": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUTBY",
#                 "name": "Tooting Broadway Underground Station",
#                 "uri": "/StopPoint/940GZZLUTBY",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUTBC",
#                 "name": "Tooting Bec Underground Station",
#                 "uri": "/StopPoint/940GZZLUTBC",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUBLM",
#                 "name": "Balham Underground Station",
#                 "uri": "/StopPoint/940GZZLUBLM",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPS",
#                 "name": "Clapham South Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPS",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPC",
#                 "name": "Clapham Common Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPC",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPN",
#                 "name": "Clapham North Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPN",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUSKW",
#                 "name": "Stockwell Underground Station",
#                 "uri": "/StopPoint/940GZZLUSKW",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUOVL",
#                 "name": "Oval Underground Station",
#                 "uri": "/StopPoint/940GZZLUOVL",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUKNG",
#                 "name": "Kennington Underground Station",
#                 "uri": "/StopPoint/940GZZLUKNG",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUEAC",
#                 "name": "Elephant & Castle Underground Station",
#                 "uri": "/StopPoint/940GZZLUEAC",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUBOR",
#                 "name": "Borough Underground Station",
#                 "uri": "/StopPoint/940GZZLUBOR",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLULNB",
#                 "name": "London Bridge Underground Station",
#                 "uri": "/StopPoint/940GZZLULNB",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUBNK",
#                 "name": "Bank Underground Station",
#                 "uri": "/StopPoint/940GZZLUBNK",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               }
#             ],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "Northern",
#               "directions": [
#                 "Golders Green Station via Bank"
#               ],
#               "lineIdentifier": {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "northern",
#                 "name": "Northern",
#                 "uri": "/Line/northern",
#                 "type": "Line",
#                 "crowding": {
#                   "$type": "Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities"
#                 },
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               "direction": "Outbound"
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "tube",
#             "name": "tube",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "1",
#             "network": "tfl"
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "isDisrupted": false,
#           "hasFixedLocations": true,
#           "scheduledDepartureTime": "2024-04-05T11:21:00",
#           "scheduledArrivalTime": "2024-04-05T11:44:00"
#         },
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 11,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Walk to EC3M 8AF",
#             "detailed": "Walk to EC3M 8AF",
#             "steps": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "Cannon Street for 73 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Cannon Street",
#                 "distance": 73,
#                 "cumulativeDistance": 73,
#                 "skyDirection": 101,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 66,
#                 "latitude": 51.51115201607,
#                 "longitude": -0.08785258998,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to King William Street, continue for 19 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "King William Street",
#                 "distance": 19,
#                 "cumulativeDistance": 92,
#                 "skyDirection": 115,
#                 "skyDirectionDescription": "SouthEast",
#                 "cumulativeTravelTime": 84,
#                 "latitude": 51.510947095700004,
#                 "longitude": -0.08686678332,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Gracechurch Street, continue for 14 metres",
#                 "turnDirection": "SLIGHT_LEFT",
#                 "streetName": "Gracechurch Street",
#                 "distance": 14,
#                 "cumulativeDistance": 106,
#                 "skyDirection": 86,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 96,
#                 "latitude": 51.51087121038,
#                 "longitude": -0.0866249689,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight left",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Eastcheap, continue for 147 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Eastcheap",
#                 "distance": 147,
#                 "cumulativeDistance": 253,
#                 "skyDirection": 92,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 228,
#                 "latitude": 51.51087690735,
#                 "longitude": -0.08642297076,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Philpot Lane, continue for 54 metres",
#                 "turnDirection": "LEFT",
#                 "streetName": "Philpot Lane",
#                 "distance": 54,
#                 "cumulativeDistance": 307,
#                 "skyDirection": 19,
#                 "skyDirectionDescription": "North",
#                 "cumulativeTravelTime": 277,
#                 "latitude": 51.51074396702,
#                 "longitude": -0.0843388959,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Turn left",
#                 "trackType": "None"
#               }
#             ]
#           },
#           "obstacles": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "UP",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "UP",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             }
#           ],
#           "departureTime": "2024-04-05T11:44:00",
#           "arrivalTime": "2024-04-05T11:55:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUBNK",
#             "platformName": "",
#             "icsCode": "1000013",
#             "individualStopId": "9400ZZLUBNK4",
#             "commonName": "Bank Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.51231267497,
#             "lon": -0.08789045923
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities",
#             "commonName": "EC3M 8AF",
#             "placeType": "StopPoint",
#             "lat": 51.511139886310005,
#             "lon": -0.08380347404
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.51231289540, -0.08790488748],[51.51265979417, -0.08822181065],[51.51265979417, -0.08822181065],[51.51265979417, -0.08822181065],[51.51289344148, -0.08821202845],[51.51115199540, -0.08785258748],[51.51115201607, -0.08785258998],[51.51113122549, -0.08768052295],[51.51110238757, -0.08756643892],[51.51094709570, -0.08686678332],[51.51087121038, -0.08662496890],[51.51087690735, -0.08642297076],[51.51086157600, -0.08603450583],[51.51080272161, -0.08573433386],[51.51074269097, -0.08536215523],[51.51075266928, -0.08487175090],[51.51074396702, -0.08433889590],[51.51119803984, -0.08406044072],[51.51113988631, -0.08380347404]]",
#             "stopPoints": [],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "",
#               "directions": [
#                 ""
#               ],
#               "direction": ""
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "walking",
#             "name": "walking",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "100",
#             "network": ""
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "distance": 307.0,
#           "isDisrupted": false,
#           "hasFixedLocations": false,
#           "scheduledDepartureTime": "2024-04-05T11:44:00",
#           "scheduledArrivalTime": "2024-04-05T11:55:00",
#           "interChangeDuration": "6",
#           "interChangePosition": "BEFORE"
#         }
#       ]
#     },
#     {
#       "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, Tfl.Api.Presentation.Entities",
#       "startDateTime": "2024-04-05T11:06:00",
#       "duration": 52,
#       "arrivalDateTime": "2024-04-05T11:58:00",
#       "alternativeRoute": false,
#       "legs": [
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 18,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Walk to Colliers Wood Station",
#             "detailed": "Walk to Colliers Wood Station",
#             "steps": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "Fleming Mead for 134 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Fleming Mead",
#                 "distance": 134,
#                 "cumulativeDistance": 134,
#                 "skyDirection": 304,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 120,
#                 "latitude": 51.41781204587,
#                 "longitude": -0.16686766494,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Myrna Close, continue for 106 metres",
#                 "turnDirection": "SLIGHT_RIGHT",
#                 "streetName": "Myrna Close",
#                 "distance": 106,
#                 "cumulativeDistance": 240,
#                 "skyDirection": 307,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 215,
#                 "latitude": 51.41743594319,
#                 "longitude": -0.16869481987,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "for 91 metres",
#                 "turnDirection": "SLIGHT_RIGHT",
#                 "streetName": "",
#                 "distance": 91,
#                 "cumulativeDistance": 331,
#                 "skyDirection": 290,
#                 "skyDirectionDescription": "West",
#                 "cumulativeTravelTime": 297,
#                 "latitude": 51.417323139009994,
#                 "longitude": -0.17010874215,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Devonshire Road, continue for 42 metres",
#                 "turnDirection": "SHARP_RIGHT",
#                 "streetName": "Devonshire Road",
#                 "distance": 42,
#                 "cumulativeDistance": 373,
#                 "skyDirection": 67,
#                 "skyDirectionDescription": "NorthEast",
#                 "cumulativeTravelTime": 334,
#                 "latitude": 51.41755699873,
#                 "longitude": -0.17126433237,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a sharp right",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Cavendish Road, continue for 530 metres",
#                 "turnDirection": "LEFT",
#                 "streetName": "Cavendish Road",
#                 "distance": 530,
#                 "cumulativeDistance": 903,
#                 "skyDirection": 334,
#                 "skyDirectionDescription": "NorthWest",
#                 "cumulativeTravelTime": 813,
#                 "latitude": 51.41770125427,
#                 "longitude": -0.17071206321,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Turn left",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to High Street Colliers Wood, continue for 82 metres",
#                 "turnDirection": "SLIGHT_LEFT",
#                 "streetName": "High Street Colliers Wood",
#                 "distance": 82,
#                 "cumulativeDistance": 985,
#                 "skyDirection": 211,
#                 "skyDirectionDescription": "SouthWest",
#                 "cumulativeTravelTime": 886,
#                 "latitude": 51.418911904320005,
#                 "longitude": -0.17742339400999999,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight left",
#                 "trackType": "None"
#               }
#             ]
#           },
#           "obstacles": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000055,
#               "position": "IDEST"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "DOWN",
#               "stopId": 1000055,
#               "position": "IDEST"
#             }
#           ],
#           "departureTime": "2024-04-05T11:06:00",
#           "arrivalTime": "2024-04-05T11:24:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "platformName": "",
#             "icsCode": "99999997",
#             "commonName": "CR4 3LY",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.417983922619996,
#             "lon": -0.16693269860999999
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUCSD",
#             "platformName": "",
#             "icsCode": "1000055",
#             "individualStopId": "9400ZZLUCSD1",
#             "commonName": "Colliers Wood Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.41867148942,
#             "lon": -0.17757677895
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.41798392262, -0.16693269861],[51.41781204587, -0.16686766494],[51.41773903025, -0.16737395288],[51.41743594319, -0.16869481987],[51.41754738028, -0.16892047567],[51.41732313901, -0.17010874215],[51.41740963178, -0.17046483304],[51.41735885072, -0.17066820558],[51.41738153554, -0.17096931754],[51.41755699873, -0.17126433237],[51.41766687658, -0.17081410882],[51.41770125427, -0.17071206321],[51.41841975140, -0.17122989875],[51.41864171866, -0.17162374065],[51.41878367680, -0.17265359639],[51.41885753716, -0.17393067094],[51.41890278052, -0.17625879406],[51.41891190432, -0.17742339401],[51.41845150654, -0.17788755291],[51.41829219777, -0.17805209081],[51.41830119533, -0.17805168757],[51.41814862856, -0.17807218157],[51.41865259533, -0.17751998757]]",
#             "stopPoints": [],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "",
#               "directions": [
#                 ""
#               ],
#               "direction": ""
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "walking",
#             "name": "walking",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "100",
#             "network": ""
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "distance": 985.0,
#           "isDisrupted": false,
#           "hasFixedLocations": true,
#           "scheduledDepartureTime": "2024-04-05T11:06:00",
#           "scheduledArrivalTime": "2024-04-05T11:24:00",
#           "interChangeDuration": "3",
#           "interChangePosition": "IDEST"
#         },
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 23,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Northern line to Bank",
#             "detailed": "Northern line towards High Barnet via Bank",
#             "steps": []
#           },
#           "obstacles": [],
#           "departureTime": "2024-04-05T11:24:00",
#           "arrivalTime": "2024-04-05T11:47:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUCSD",
#             "platformName": "",
#             "icsCode": "1000055",
#             "individualStopId": "9400ZZLUCSD1",
#             "commonName": "Colliers Wood Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.41867148942,
#             "lon": -0.17757677895
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUBNK",
#             "platformName": "",
#             "icsCode": "1000013",
#             "individualStopId": "9400ZZLUBNK4",
#             "commonName": "Bank Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.51231267497,
#             "lon": -0.08789045923
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.41865453159, -0.17752466317],[51.42004167281, -0.17605525225],[51.42051261610, -0.17569131773],[51.42098221542, -0.17524113162],[51.42190455397, -0.17441331916],[51.42287789609, -0.17339645375],[51.42350342533, -0.17256602482],[51.42429588915, -0.17148438326],[51.42508182381, -0.17056119084],[51.42552511443, -0.17015510970],[51.42668916494, -0.16925991069],[51.42714098846, -0.16882469139],[51.42780359581, -0.16810627263],[51.42780359581, -0.16810627263],[51.42916596914, -0.16662906493],[51.43083885686, -0.16492209173],[51.43135267122, -0.16442675961],[51.43160047801, -0.16417226097],[51.43218753599, -0.16376029380],[51.43273236097, -0.16352264912],[51.43320393799, -0.16320161573],[51.43361102797, -0.16278245426],[51.43411471844, -0.16221553814],[51.43488730261, -0.16101916030],[51.43520158169, -0.16041665528],[51.43572319044, -0.15927346977],[51.43587418287, -0.15905448961],[51.43587418287, -0.15905448961],[51.43654966492, -0.15807483129],[51.43735278320, -0.15710729855],[51.43762753383, -0.15685164124],[51.43816132106, -0.15648483345],[51.43902694365, -0.15606148735],[51.44009609524, -0.15542848039],[51.44095944991, -0.15486129450],[51.44399160676, -0.15225676731],[51.44399160676, -0.15225676731],[51.44468590878, -0.15166032709],[51.44511070155, -0.15122584896],[51.44534005021, -0.15094316431],[51.44587554227, -0.15011564918],[51.44625425965, -0.14961105305],[51.44668040675, -0.14926283198],[51.44759719549, -0.14866450053],[51.44859486238, -0.14806287207],[51.44904238673, -0.14792962974],[51.45110663277, -0.14767338424],[51.45177256774, -0.14770400099],[51.45230188195, -0.14762500560],[51.45294370606, -0.14726798660],[51.45328008596, -0.14699203546],[51.45328008596, -0.14699203546],[51.45364502598, -0.14669264955],[51.45559254936, -0.14474257091],[51.45705419429, -0.14334463493],[51.45816364421, -0.14242154005],[51.45946066858, -0.14141880462],[51.45984139848, -0.14104345804],[51.46013248737, -0.14068614349],[51.46115167299, -0.13917636997],[51.46168593406, -0.13827649603],[51.46194685465, -0.13771883487],[51.46219535667, -0.13694573380],[51.46223616889, -0.13678463157],[51.46223616889, -0.13678463157],[51.46242382149, -0.13604387641],[51.46264718254, -0.13538695146],[51.46349170934, -0.13307790329],[51.46426287774, -0.13124685439],[51.46471619555, -0.13035013310],[51.46505034827, -0.12987577569],[51.46549279874, -0.12942577641],[51.46570744264, -0.12927772237],[51.46570744264, -0.12927772237],[51.46751188618, -0.12803301723],[51.46813268438, -0.12748928683],[51.46858296234, -0.12696692276],[51.46976142379, -0.12530604484],[51.47049213046, -0.12432578557],[51.47139357547, -0.12333848806],[51.47180905450, -0.12286171332],[51.47180905450, -0.12286171332],[51.47287706873, -0.12163608392],[51.47311625063, -0.12141026805],[51.47340036541, -0.12118260365],[51.47460409854, -0.11998115399],[51.47499281926, -0.11954757148],[51.47564721317, -0.11885824934],[51.47737050325, -0.11697285257],[51.47799907712, -0.11635652516],[51.47921081858, -0.11509688795],[51.48131352004, -0.11276347811],[51.48155300626, -0.11255231007],[51.48155300626, -0.11255231007],[51.48283859238, -0.11141869439],[51.48440556499, -0.10988484800],[51.48585476168, -0.10829815511],[51.48773893155, -0.10636204829],[51.48791610582, -0.10619626235],[51.48843749893, -0.10568255305],[51.48843749893, -0.10568255305],[51.48924385794, -0.10488804945],[51.49046468700, -0.10364181592],[51.49155559532, -0.10270342011],[51.49282122758, -0.10089338082],[51.49315851894, -0.10062005911],[51.49354307425, -0.10048882730],[51.49480375326, -0.10059488862],[51.49499201222, -0.10053355917],[51.49499201222, -0.10053355917],[51.49510789605, -0.10049580723],[51.49586405413, -0.09998895309],[51.49664926916, -0.09961053500],[51.49711855449, -0.09915880487],[51.49823217976, -0.09795988205],[51.49906884606, -0.09687329133],[51.50011042139, -0.09511535238],[51.50057266965, -0.09423159047],[51.50099315377, -0.09350892153],[51.50099315377, -0.09350892153],[51.50105382 ...
#             "stopPoints": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUTBY",
#                 "name": "Tooting Broadway Underground Station",
#                 "uri": "/StopPoint/940GZZLUTBY",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUTBC",
#                 "name": "Tooting Bec Underground Station",
#                 "uri": "/StopPoint/940GZZLUTBC",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUBLM",
#                 "name": "Balham Underground Station",
#                 "uri": "/StopPoint/940GZZLUBLM",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPS",
#                 "name": "Clapham South Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPS",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPC",
#                 "name": "Clapham Common Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPC",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUCPN",
#                 "name": "Clapham North Underground Station",
#                 "uri": "/StopPoint/940GZZLUCPN",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
# ...
#                 "uri": "/StopPoint/940GZZLULNB",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "940GZZLUBNK",
#                 "name": "Bank Underground Station",
#                 "uri": "/StopPoint/940GZZLUBNK",
#                 "type": "StopPoint",
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               }
#             ],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "Northern",
#               "directions": [
#                 "Golders Green Station via Bank"
#               ],
#               "lineIdentifier": {
#                 "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#                 "id": "northern",
#                 "name": "Northern",
#                 "uri": "/Line/northern",
#                 "type": "Line",
#                 "crowding": {
#                   "$type": "Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities"
#                 },
#                 "routeType": "Unknown",
#                 "status": "Unknown"
#               },
#               "direction": "Outbound"
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "tube",
#             "name": "tube",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "1",
#             "network": "tfl"
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "isDisrupted": false,
#           "hasFixedLocations": true,
#           "scheduledDepartureTime": "2024-04-05T11:27:00",
#           "scheduledArrivalTime": "2024-04-05T11:50:00"
#         },
#         {
#           "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities",
#           "duration": 11,
#           "instruction": {
#             "$type": "Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities",
#             "summary": "Walk to EC3M 8AF",
#             "detailed": "Walk to EC3M 8AF",
#             "steps": [
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "Cannon Street for 73 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Cannon Street",
#                 "distance": 73,
#                 "cumulativeDistance": 73,
#                 "skyDirection": 101,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 66,
#                 "latitude": 51.51115201607,
#                 "longitude": -0.08785258998,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to King William Street, continue for 19 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "King William Street",
#                 "distance": 19,
#                 "cumulativeDistance": 92,
#                 "skyDirection": 115,
#                 "skyDirectionDescription": "SouthEast",
#                 "cumulativeTravelTime": 84,
#                 "latitude": 51.510947095700004,
#                 "longitude": -0.08686678332,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Gracechurch Street, continue for 14 metres",
#                 "turnDirection": "SLIGHT_LEFT",
#                 "streetName": "Gracechurch Street",
#                 "distance": 14,
#                 "cumulativeDistance": 106,
#                 "skyDirection": 86,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 96,
#                 "latitude": 51.51087121038,
#                 "longitude": -0.0866249689,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Take a slight left",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Eastcheap, continue for 147 metres",
#                 "turnDirection": "STRAIGHT",
#                 "streetName": "Eastcheap",
#                 "distance": 147,
#                 "cumulativeDistance": 253,
#                 "skyDirection": 92,
#                 "skyDirectionDescription": "East",
#                 "cumulativeTravelTime": 228,
#                 "latitude": 51.51087690735,
#                 "longitude": -0.08642297076,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Continue along ",
#                 "trackType": "None"
#               },
#               {
#                 "$type": "Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities",
#                 "description": "on to Philpot Lane, continue for 54 metres",
#                 "turnDirection": "LEFT",
#                 "streetName": "Philpot Lane",
#                 "distance": 54,
#                 "cumulativeDistance": 307,
#                 "skyDirection": 19,
#                 "skyDirectionDescription": "North",
#                 "cumulativeTravelTime": 277,
#                 "latitude": 51.51074396702,
#                 "longitude": -0.0843388959,
#                 "pathAttribute": {
#                   "$type": "Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities"
#                 },
#                 "descriptionHeading": "Turn left",
#                 "trackType": "None"
#               }
#             ]
#           },
#           "obstacles": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "UP",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "ESCALATOR",
#               "incline": "UP",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             },
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities",
#               "type": "WALKWAY",
#               "incline": "LEVEL",
#               "stopId": 1000013,
#               "position": "BEFORE"
#             }
#           ],
#           "departureTime": "2024-04-05T11:50:00",
#           "arrivalTime": "2024-04-05T12:01:00",
#           "departurePoint": {
#             "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#             "naptanId": "940GZZLUBNK",
#             "platformName": "",
#             "icsCode": "1000013",
#             "individualStopId": "9400ZZLUBNK4",
#             "commonName": "Bank Underground Station",
#             "placeType": "StopPoint",
#             "additionalProperties": [],
#             "lat": 51.51231267497,
#             "lon": -0.08789045923
#           },
#           "arrivalPoint": {
#             "$type": "Tfl.Api.Presentation.Entities.Place, Tfl.Api.Presentation.Entities",
#             "commonName": "EC3M 8AF",
#             "placeType": "StopPoint",
#             "lat": 51.511139886310005,
#             "lon": -0.08380347404
#           },
#           "path": {
#             "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.Path, Tfl.Api.Presentation.Entities",
#             "lineString": "[[51.51231289540, -0.08790488748],[51.51265979417, -0.08822181065],[51.51265979417, -0.08822181065],[51.51265979417, -0.08822181065],[51.51289344148, -0.08821202845],[51.51115199540, -0.08785258748],[51.51115201607, -0.08785258998],[51.51113122549, -0.08768052295],[51.51110238757, -0.08756643892],[51.51094709570, -0.08686678332],[51.51087121038, -0.08662496890],[51.51087690735, -0.08642297076],[51.51086157600, -0.08603450583],[51.51080272161, -0.08573433386],[51.51074269097, -0.08536215523],[51.51075266928, -0.08487175090],[51.51074396702, -0.08433889590],[51.51119803984, -0.08406044072],[51.51113988631, -0.08380347404]]",
#             "stopPoints": [],
#             "elevation": []
#           },
#           "routeOptions": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.RouteOption, Tfl.Api.Presentation.Entities",
#               "name": "",
#               "directions": [
#                 ""
#               ],
#               "direction": ""
#             }
#           ],
#           "mode": {
#             "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#             "id": "walking",
#             "name": "walking",
#             "type": "Mode",
#             "routeType": "Unknown",
#             "status": "Unknown",
#             "motType": "100",
#             "network": ""
#           },
#           "disruptions": [],
#           "plannedWorks": [],
#           "distance": 307.0,
#           "isDisrupted": false,
#           "hasFixedLocations": false,
#           "scheduledDepartureTime": "2024-04-05T11:50:00",
#           "scheduledArrivalTime": "2024-04-05T12:01:00",
#           "interChangeDuration": "6",
#           "interChangePosition": "BEFORE"
#         }
#       ]
#     }
#   ],
#   "lines": [
#     {
#       "$type": "Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities",
#       "id": "northern",
#       "name": "Northern",
#       "modeName": "tube",
#       "disruptions": [],
#       "created": "2024-04-03T17:10:35.867Z",
#       "modified": "2024-04-03T17:10:35.867Z",
#       "lineStatuses": [
#         {
#           "$type": "Tfl.Api.Presentation.Entities.LineStatus, Tfl.Api.Presentation.Entities",
#           "id": 0,
#           "lineId": "northern",
#           "statusSeverity": 5,
#           "statusSeverityDescription": "Part Closure",
#           "reason": "NORTHERN LINE: Tuesday 2 until Thursday 11 April, no service between Golders Green and Edgware due to planned engineering works. Replacement buses will operate",
#           "created": "0001-01-01T00:00:00",
#           "validityPeriods": [
#             {
#               "$type": "Tfl.Api.Presentation.Entities.ValidityPeriod, Tfl.Api.Presentation.Entities",
#               "fromDate": "2024-04-02T03:30:00Z",
#               "toDate": "2024-04-12T00:29:00Z",
#               "isNow": false
#             }
#           ],
#           "disruption": {
#             "$type": "Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities",
#             "category": "PlannedWork",
#             "categoryDescription": "PlannedWork",
#             "description": "NORTHERN LINE: Tuesday 2 until Thursday 11 April, no service between Golders Green and Edgware due to planned engineering works. Replacement buses will operate",
#             "additionalInfo": "Replacement Buses will operate as follows:NL1 - Canons Park (for Jubilee line) - Edgware - Burnt Oak - Colindale - Hendon Central - Brent Cross (Golders Green Road) - Golders Green\u00a0On Weekdays only there will be additional buses operating between 0630 - 0900 & 1500 - 1930 calling at Colindale - Hendon Central - Brent Cross (Golders Green Road) - Golders Green",
#             "created": "2024-03-07T10:26:00Z",
#             "affectedRoutes": [],
#             "affectedStops": [],
#             "closureText": "partClosure"
#           }
#         }
#       ],
#       "routeSections": [],
#       "serviceTypes": [
#         {
#           "$type": "Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities",
#           "name": "Regular",
#           "uri": "/Line/Route?ids=Northern&serviceTypes=Regular"
#         },
#         {
#           "$type": "Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities",
#           "name": "Night",
#           "uri": "/Line/Route?ids=Northern&serviceTypes=Night"
#         }
#       ],
#       "crowding": {
#         "$type": "Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities"
#       }
#     }
#   ],
#   "stopMessages": [],
#   "recommendedMaxAgeMinutes": 5,
#   "searchCriteria": {
#     "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.SearchCriteria, Tfl.Api.Presentation.Entities",
#     "dateTime": "2024-04-05T12:05:00",
#     "dateTimeType": "Arriving",
#     "timeAdjustments": {
#       "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustments, Tfl.Api.Presentation.Entities",
#       "earliest": {
#         "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustment, Tfl.Api.Presentation.Entities",
#         "date": "20240405",
#         "time": "0300",
#         "timeIs": "arriving",
#         "uri": "/journey/journeyresults/cr4%203ly/to/ec3m%208af?timeIs=arriving&journeypreference=leastinterchange&accessibilitypreference=norequirements&walkingspeed=slow&cyclepreference=none&bikeproficiency=easy&time=0300&date=20240405"
#       },
#       "earlier": {
#         "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustment, Tfl.Api.Presentation.Entities",
#         "date": "20240405",
#         "time": "1154",
#         "timeIs": "arriving",
#         "uri": "/journey/journeyresults/cr4%203ly/to/ec3m%208af?timeIs=arriving&journeypreference=leastinterchange&accessibilitypreference=norequirements&walkingspeed=slow&cyclepreference=none&bikeproficiency=easy&time=1154&date=20240405"
#       },
#       "later": {
#         "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustment, Tfl.Api.Presentation.Entities",
#         "date": "20240405",
#         "time": "1220",
#         "timeIs": "arriving",
#         "uri": "/journey/journeyresults/cr4%203ly/to/ec3m%208af?timeIs=arriving&journeypreference=leastinterchange&accessibilitypreference=norequirements&walkingspeed=slow&cyclepreference=none&bikeproficiency=easy&time=1220&date=20240405"
#       },
#       "latest": {
#         "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.TimeAdjustment, Tfl.Api.Presentation.Entities",
#         "date": "20240406",
#         "time": "0300",
#         "timeIs": "arriving",
#         "uri": "/journey/journeyresults/cr4%203ly/to/ec3m%208af?timeIs=arriving&journeypreference=leastinterchange&accessibilitypreference=norequirements&walkingspeed=slow&cyclepreference=none&bikeproficiency=easy&time=0300&date=20240406"
#       }
#     }
#   },
#   "journeyVector": {
#     "$type": "Tfl.Api.Presentation.Entities.JourneyPlanner.JourneyVector, Tfl.Api.Presentation.Entities",
#     "from": "CR43LY",
#     "to": "EC3M8AF",
#     "via": "",
#     "uri": "/journey/journeyresults/cr4%203ly/to/ec3m%208af?timeis=arriving&journeypreference=leastinterchange&accessibilitypreference=norequirements&walkingspeed=slow&cyclepreference=none&bikeproficiency=easy"
#   }
# }

# %%
 # !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
# Assuming 'data' is your parsed JSON response from the TfL API
journeys = data['journeys']

# %%
# Check the number of journeys
print(f"Number of journeys: {len(journeys)}")

# Optionally, inspect the first journey
if journeys:  # Check if the list is not empty
    print(journeys[0])  # Print the first journey to inspect its structure
# Out:
# Number of journeys: 3
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, Tfl.Api.Presentation.Entities', 'startDateTime': '2024-04-05T11:03:00', 'duration': 52, 'arrivalDateTime': '2024-04-05T11:55:00', 'alternativeRoute': False, 'legs': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities', 'duration': 18, 'instruction': {'$type': 'Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities', 'summary': 'Walk to Colliers Wood Station', 'detailed': 'Walk to Colliers Wood Station', 'steps': [{'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'Fleming Mead for 134 metres', 'turnDirection': 'STRAIGHT', 'streetName': 'Fleming Mead', 'distance': 134, 'cumulativeDistance': 134, 'skyDirection': 304, 'skyDirectionDescription': 'NorthWest', 'cumulativeTravelTime': 120, 'latitude': 51.41781204587, 'longitude': -0.16686766494, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Continue along ', 'trackType': 'None'}, {'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'on to Myrna Close, continue for 106 metres', 'turnDirection': 'SLIGHT_RIGHT', 'streetName': 'Myrna Close', 'distance': 106, 'cumulativeDistance': 240, 'skyDirection': 307, 'skyDirectionDescription': 'NorthWest', 'cumulativeTravelTime': 215, 'latitude': 51.41743594319, 'longitude': -0.16869481987, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Take a slight right', 'trackType': 'None'}, {'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'for 91 metres', 'turnDirection': 'SLIGHT_RIGHT', 'streetName': '', 'distance': 91, 'cumulativeDistance': 331, 'skyDirection': 290, 'skyDirectionDescription': 'West', 'cumulativeTravelTime': 297, 'latitude': 51.417323139009994, 'longitude': -0.17010874215, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Take a slight right', 'trackType': 'None'}, {'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'on to Devonshire Road, continue for 42 metres', 'turnDirection': 'SHARP_RIGHT', 'streetName': 'Devonshire Road', 'distance': 42, 'cumulativeDistance': 373, 'skyDirection': 67, 'skyDirectionDescription': 'NorthEast', 'cumulativeTravelTime': 334, 'latitude': 51.41755699873, 'longitude': -0.17126433237, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Take a sharp right', 'trackType': 'None'}, {'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'on to Cavendish Road, continue for 530 metres', 'turnDirection': 'LEFT', 'streetName': 'Cavendish Road', 'distance': 530, 'cumulativeDistance': 903, 'skyDirection': 334, 'skyDirectionDescription': 'NorthWest', 'cumulativeTravelTime': 813, 'latitude': 51.41770125427, 'longitude': -0.17071206321, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Turn left', 'trackType': 'None'}, {'$type': 'Tfl.Api.Presentation.Entities.InstructionStep, Tfl.Api.Presentation.Entities', 'description': 'on to High Street Colliers Wood, continue for 82 metres', 'turnDirection': 'SLIGHT_LEFT', 'streetName': 'High Street Colliers Wood', 'distance': 82, 'cumulativeDistance': 985, 'skyDirection': 211, 'skyDirectionDescription': 'SouthWest', 'cumulativeTravelTime': 886, 'latitude': 51.418911904320005, 'longitude': -0.17742339400999999, 'pathAttribute': {'$type': 'Tfl.Api.Presentation.Entities.PathAttribute, Tfl.Api.Presentation.Entities'}, 'descriptionHeading': 'Take a slight left', 'trackType': 'None'}]}, 'obstacles': [{'$type': 'Tfl.Api.Pr ...

# %%
import folium

def add_leg_to_map(_map, leg):
    # Extract start and end coordinates
    start_coord = (leg['departurePoint']['lat'], leg['departurePoint']['lon'])
    end_coord = (leg['arrivalPoint']['lat'], leg['arrivalPoint']['lon'])

    # Add markers
    folium.Marker(start_coord, popup='Start', icon=folium.Icon(color='green')).add_to(_map)
    folium.Marker(end_coord, popup='End', icon=folium.Icon(color='red')).add_to(_map)

    # Draw the leg path if available
    if 'path' in leg and 'lineString' in leg['path']:
        path_coords = [[float(coord) for coord in point.split(',')] for point in leg['path']['lineString'][2:-2].split('],[')]
        folium.PolyLine(locations=path_coords, color='blue').add_to(_map)

# Initialize the base map
first_leg = journeys[0]['legs'][0]
base_map = folium.Map(location=[first_leg['departurePoint']['lat'], first_leg['departurePoint']['lon']], zoom_start=14)

# Add each leg to the map
for journey in journeys:
    for leg in journey['legs']:
        add_leg_to_map(base_map, leg)

# Display the map
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81eb9c7e4bda49c222b01fe653267a06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81eb9c7e4bda49c222b01fe653267a06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81eb9c7e4bda49c222b01fe653267a06 = L.map(
#                 &quot;map_81eb9c7e4bda49c222b01fe653267a06&quot;,
#                 {
#                     center: [51.417983922619996, -0.16693269860999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7adc08b862e7e5ba78d2aa24aeaf194 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81eb9c7e4bda49c222b01fe653267a06);
#
#
#             var marker_d346b34084d10fdb338d45ab3a813aaa = L.marker(
#                 [51.417983922619996, -0.16693269860999999],
#                 {}
#             ).addTo(map_81eb9c7e4bda49c222b01fe653267a06);
#
#
#             var icon_4ef3c58dde288e6050f5c55f4959dd86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d346b34084d10fdb338d45ab3a813aaa.setIcon(icon_4ef3c58dde288e6050f5c55f4959dd86);
#
#
#         var popup_7b94b8f692ef1d85840cd58626dceb91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7dd5d0c469c05492bcb86f2904d048e = $(`&lt;div id=&quot;html_e7dd5d0c469c05492bcb86f2904d048e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_7b94b8f692ef1d85840cd58626dceb91.setContent(html_e7dd5d0c469c05492bcb86f2904d048e);
#
#
#
#         marker_d346b34084d10fdb338d45ab3a813aaa.bindPopup(popup_7b94b8f692ef1d85840cd58626dceb91)
#         ;
#
#
#
#
#             var marker_534d98abab598c58f1b4de5750a270a2 = L.marker(
#                 [51.41867148942, -0.17757677895],
#                 {}
#             ).addTo(map_81eb9c7e4bda49c222b01fe653267a06);
#
#
#             var icon_438239c8e857452c24a68f8eeb1be255 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_534d98abab598c58f1b4de5750a270a2.setIcon(icon_438239c8e857452c24a68f8eeb1be255);
#
#
#         var popup_c12054d4d41c1234d1be5ecf0cc0d32c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40c203165474d13e3607236b89273850 = $(`&lt;div id=&quot;html_40c203165474d13e3607236b89273850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_c12054d4d41c1234d1be5ecf0cc0d32c.setContent(html_40c203165474d13e3607236b89273850);
#
#
#
#         marker_534d98abab598c58f1b4de5750a270a2.bindPopup(popup_c12054d4d41c1234d1be5ecf0cc0d32c)
#         ;
#
#
#
#
#             var poly_line_24afb0bf35686e53c42f8e674d49c838 = L.polyline(
#                 [[51.41798392262, -0.16693269861], [51.41781204587, -0.16686766494], [51.41773903025, -0.16737395288], [51.41743594319, -0.16869481987], [51.41754738028, -0.16892047567], [51.41732313901, -0.17010874215], [51.41740963178, -0.17046483304], [51.41735885072, -0.17066820558], [51.41738153554, -0.17096931754], [51.41755699873, -0.17126433237], [51.41766687658, -0.17081410882], [51.41770125427, -0.17071206321], [51.4184197514, -0.17122989875], [51.41864171866, -0.17162374065], [51.4187836768, -0.17265359639], [51.41885753716, -0.17393067094], [51.41890278052, -0.17625879406], [51.41891190432, -0.17742339401], [51.41845150654, -0.17788755291], [51.41829219777, -0.17805209081], [51.41830119533, -0.17805168757], [51.41814862856, -0.17807218157], [51.41865259533, -0.17751998757]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_81eb9c7e4bda49c222b01fe653267a06);
#
#
#             var marker_b40e45f1faf8819cf5e1d5524ccdb3d1 = L.marker(
#                 [51.41867148942, -0.17757677895],
